# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.model_selection import KFold
import numpy as np
import cv2 as cv
import os
import keras

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
print(X_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
DataDir = "/content/drive/MyDrive/FEC - version 2/CK+48" # training dataset
Classes = ["anger", "contempt", "disgust", "fear", "happy", "sadness", "surprise"] # list of classes
from tensorflow.keras.utils import to_categorical

def create_training_data():
  X, y = [], []
  for Class in Classes:
      path = os.path.join(DataDir, Class)
      class_num = Classes.index(Class) # Label
      for img in os.listdir(path):
          try:
              img_array = cv.imread(os.path.join(path, img), 0)
              X.append(img_array)
              y.append(class_num)
          except Exception as e:
              pass

  return np.array(X), to_categorical(np.array(y), num_classes=7)

X, y = create_training_data()

# %%
X.shape
# Out:
# (981, 48, 48)

# %%
y.shape
# Out:
# (981, 7)

# %%
from keras.preprocessing.image import ImageDataGenerator 
datagen = ImageDataGenerator( 
    rescale=1./255,
    rotation_range = 10,
    horizontal_flip = True,
    width_shift_range=0.1,
    height_shift_range=0.1,
    fill_mode = 'nearest')

# %%
X = X.reshape(X.shape[0], 48, 48, 1)
datagen.fit(X)

# %%
print(X.shape)
# Out:
# (981, 48, 48, 1)

# %%
train_flow = datagen.flow(X, y, batch_size=32)

# %%
print(train_flow)
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7fd15c71db10>

# %%
from tensorflow.keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.regularizers import l1, l2
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix

def get_model(input_shape=(48,48,1)):
# first input model
  visible = Input(shape=input_shape, name='input')
  num_classes = 7

  #the 1-st block
  conv1_1 = Conv2D(64, kernel_size=3, activation='relu', padding='same', name = 'conv1_1')(visible)
  conv1_1 = BatchNormalization()(conv1_1)
  conv1_2 = Conv2D(64, kernel_size=3, activation='relu', padding='same', name = 'conv1_2')(conv1_1)
  conv1_2 = BatchNormalization()(conv1_2)
  pool1_1 = MaxPooling2D(pool_size=(2,2), name = 'pool1_1')(conv1_2)
  drop1_1 = Dropout(0.3, name = 'drop1_1')(pool1_1)

  #the 2-nd block
  conv2_1 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_1')(drop1_1)
  conv2_1 = BatchNormalization()(conv2_1)
  conv2_2 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_2')(conv2_1)
  conv2_2 = BatchNormalization()(conv2_2)
  conv2_3 = Conv2D(128, kernel_size=3, activation='relu', padding='same', name = 'conv2_3')(conv2_2)
  conv2_2 = BatchNormalization()(conv2_3)
  pool2_1 = MaxPooling2D(pool_size=(2,2), name = 'pool2_1')(conv2_3)
  drop2_1 = Dropout(0.3, name = 'drop2_1')(pool2_1)

  #the 3-rd block
  conv3_1 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_1')(drop2_1)
  conv3_1 = BatchNormalization()(conv3_1)
  conv3_2 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_2')(conv3_1)
  conv3_2 = BatchNormalization()(conv3_2)
  conv3_3 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_3')(conv3_2)
  conv3_3 = BatchNormalization()(conv3_3)
  conv3_4 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv3_4')(conv3_3)
  conv3_4 = BatchNormalization()(conv3_4)
  pool3_1 = MaxPooling2D(pool_size=(2,2), name = 'pool3_1')(conv3_4)
  drop3_1 = Dropout(0.3, name = 'drop3_1')(pool3_1)

  #the 4-th block
  conv4_1 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_1')(drop3_1)
  conv4_1 = BatchNormalization()(conv4_1)
  conv4_2 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_2')(conv4_1)
  conv4_2 = BatchNormalization()(conv4_2)
  conv4_3 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_3')(conv4_2)
  conv4_3 = BatchNormalization()(conv4_3)
  conv4_4 = Conv2D(256, kernel_size=3, activation='relu', padding='same', name = 'conv4_4')(conv4_3)
  conv4_4 = BatchNormalization()(conv4_4)
  pool4_1 = MaxPooling2D(pool_size=(2,2), name = 'pool4_1')(conv4_4)
  drop4_1 = Dropout(0.3, name = 'drop4_1')(pool4_1)
  
  #the 5-th block
  conv5_1 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_1')(drop4_1)
  conv5_1 = BatchNormalization()(conv5_1)
  conv5_2 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_2')(conv5_1)
  conv5_2 = BatchNormalization()(conv5_2)
  conv5_3 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_3')(conv5_2)
  conv5_3 = BatchNormalization()(conv5_3)
  conv5_4 = Conv2D(512, kernel_size=3, activation='relu', padding='same', name = 'conv5_4')(conv5_3)
  conv5_3 = BatchNormalization()(conv5_3)
  pool5_1 = MaxPooling2D(pool_size=(2,2), name = 'pool5_1')(conv5_4)
  drop5_1 = Dropout(0.3, name = 'drop5_1')(pool5_1)
  
  #Flatten and output
  flatten = Flatten(name = 'flatten')(drop5_1)
  ouput = Dense(num_classes, activation='softmax', name = 'output')(flatten)
  
  # create model 
  model = Model(inputs =visible, outputs = ouput)
  
  # summary layers
  print(model.summary())
  
  return model

# %%
def get_model_VGG():
  model = Sequential()
  model.add(ZeroPadding2D((1,1),input_shape=(48,48,1)))
  model.add(Convolution2D(64, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(64, 3, 3, activation='relu'))
  model.add(MaxPooling2D((2,2), strides=(2,2)))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(128, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(128, 3, 3, activation='relu'))
  model.add(MaxPooling2D((2,2), strides=(2,2)))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(256, 3, 3, activation='relu'))
  model.add(MaxPooling2D((2,2), strides=(2,2)))

  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(MaxPooling2D((2,2), strides=(2,2)))


  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(ZeroPadding2D((1,1)))
  model.add(Convolution2D(512, 3, 3, activation='relu'))
  model.add(MaxPooling2D((2,2), strides=(2,2)))

  model.add(Flatten())
  model.add(Dense(4096, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(4096, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(7, activation='softmax'))

  model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])
  
  return model

# %%
BATCH_SIZE, num_epochs, num_folds = 32, 30, 10

X = X.astype('float32')
X = X / 255

accuracy_list, loss_list = [], []
# Định nghĩa K-Fold CV
kfold = KFold(n_splits=num_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_idx = 1

for train_ids, val_ids in kfold.split(X, y):

  model = get_model()

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  
  print("Bắt đầu train Fold ", fold_idx)

  # Train model
  model.fit(X[train_ids], y[train_ids],
              batch_size=BATCH_SIZE,
              epochs=num_epochs,
            verbose=1)

  # Test và in kết quả
  scores = model.evaluate(X[val_ids], y[val_ids], verbose=0)
  print("Đã train xong Fold ", fold_idx)

  # Thêm thông tin accuracy và loss vào list
  accuracy_list.append(scores[1] * 100)
  loss_list.append(scores[0])

  # Sang Fold tiếp theo
  fold_idx = fold_idx + 1
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_17 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_18 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_19 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_20 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_22 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_23 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_24 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_25 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_26 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_27 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_28 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_29 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_30 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_31 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_32 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  1
# Epoch 1/30
# 28/28 [==============================] - 5s 100ms/step - loss: 4.2560 - accuracy: 0.2540
# Epoch 2/30
# 28/28 [==============================] - 3s 96ms/step - loss: 3.3057 - accuracy: 0.3900
# Epoch 3/30
# 28/28 [==============================] - 3s 95ms/step - loss: 2.3818 - accuracy: 0.4841
# Epoch 4/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.8086 - accuracy: 0.5816
# Epoch 5/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.7047 - accuracy: 0.6066
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.1120 - accuracy: 0.6497
# Epoch 7/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.8097 - accuracy: 0.6859
# Epoch 8/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.7339 - accuracy: 0.7245
# Epoch 9/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.5105 - accuracy: 0.7937
# Epoch 10/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4461 - accuracy: 0.8175
# Epoch 11/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2599 - accuracy: 0.8957
# Epoch 12/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.3474 - accuracy: 0.8696
# Epoch 13/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2664 - accuracy: 0.8946
# Epoch 14/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2639 - accuracy: 0.9036
# Epoch 15/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1481 - accuracy: 0.9524
# Epoch 16/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2391 - accuracy: 0.9252
# Epoch 17/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2152 - accuracy: 0.9252
# Epoch 18/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1135 - accuracy: 0.9592
# Epoch 19/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2008 - accuracy: 0.9456
# Epoch 20/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1929 - accuracy: 0.9308
# Epoch 21/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1389 - accuracy: 0.9535
# Epoch 22/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.1351 - accuracy: 0.9580
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1686 - accuracy: 0.9524
# Epoch 24/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1590 - accuracy: 0.9524
# Epoch 25/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.1249 - accuracy: 0.9580
# Epoch 26/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0742 - accuracy: 0.9694
# Epoch 27/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0980 - accuracy: 0.9751
# Epoch 28/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0655 - accuracy: 0.9773
# Epoch 29/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0862 - accuracy: 0.9751
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1344 - accuracy: 0.9569
# Đã train xong Fold  1
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_34 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_35 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_36 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_37 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_39 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_40 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_41 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_42 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_43 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_44 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_45 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_46 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_47 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_48 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_49 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  2
# Epoch 1/30
# 28/28 [==============================] - 6s 131ms/step - loss: 3.9762 - accuracy: 0.2424
# Epoch 2/30
# 28/28 [==============================] - 3s 101ms/step - loss: 3.5148 - accuracy: 0.3420
# Epoch 3/30
# 28/28 [==============================] - 3s 96ms/step - loss: 2.7955 - accuracy: 0.4881
# Epoch 4/30
# 28/28 [==============================] - 3s 97ms/step - loss: 2.9045 - accuracy: 0.5210
# Epoch 5/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.9621 - accuracy: 0.5934
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.7682 - accuracy: 0.6772
# Epoch 7/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.4228 - accuracy: 0.7101
# Epoch 8/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.9498 - accuracy: 0.7486
# Epoch 9/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.8051 - accuracy: 0.7814
# Epoch 10/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.7205 - accuracy: 0.7973
# Epoch 11/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4599 - accuracy: 0.8358
# Epoch 12/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.5093 - accuracy: 0.8279
# Epoch 13/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.5766 - accuracy: 0.7905
# Epoch 14/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4103 - accuracy: 0.8618
# Epoch 15/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2728 - accuracy: 0.9083
# Epoch 16/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1892 - accuracy: 0.9388
# Epoch 17/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1650 - accuracy: 0.9422
# Epoch 18/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2725 - accuracy: 0.9151
# Epoch 19/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.3055 - accuracy: 0.9003
# Epoch 20/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1854 - accuracy: 0.9354
# Epoch 21/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1642 - accuracy: 0.9388
# Epoch 22/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1639 - accuracy: 0.9422
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2888 - accuracy: 0.9185
# Epoch 24/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2895 - accuracy: 0.9151
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1228 - accuracy: 0.9490
# Epoch 26/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1380 - accuracy: 0.9468
# Epoch 27/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1239 - accuracy: 0.9570
# Epoch 28/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0746 - accuracy: 0.9740
# Epoch 29/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0849 - accuracy: 0.9762
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0609 - accuracy: 0.9807
# Đã train xong Fold  2
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_51 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_52 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_53 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_54 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_56 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_57 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_58 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_59 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_60 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_61 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_62 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_63 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_64 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_65 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_66 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  3
# Epoch 1/30
# 28/28 [==============================] - 5s 98ms/step - loss: 4.4488 - accuracy: 0.2231
# Epoch 2/30
# 28/28 [==============================] - 3s 96ms/step - loss: 2.6399 - accuracy: 0.3783
# Epoch 3/30
# 28/28 [==============================] - 3s 96ms/step - loss: 2.2001 - accuracy: 0.4870
# Epoch 4/30
# 28/28 [==============================] - 3s 95ms/step - loss: 2.3388 - accuracy: 0.4496
# Epoch 5/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.1904 - accuracy: 0.5629
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.9791 - accuracy: 0.6421
# Epoch 7/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.0689 - accuracy: 0.6059
# Epoch 8/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.7684 - accuracy: 0.7022
# Epoch 9/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.5732 - accuracy: 0.7588
# Epoch 10/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4897 - accuracy: 0.7916
# Epoch 11/30
# 28/28 [==============================] - 3s 98ms/step - loss: 0.4488 - accuracy: 0.8290
# Epoch 12/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.3416 - accuracy: 0.8777
# Epoch 13/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.3051 - accuracy: 0.8834
# Epoch 14/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.4517 - accuracy: 0.8482
# Epoch 15/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.5484 - accuracy: 0.8097
# Epoch 16/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.3608 - accuracy: 0.8709
# Epoch 17/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2506 - accuracy: 0.9060
# Epoch 18/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1795 - accuracy: 0.9264
# Epoch 19/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1764 - accuracy: 0.9434
# Epoch 20/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1688 - accuracy: 0.9422
# Epoch 21/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0964 - accuracy: 0.9672
# Epoch 22/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0982 - accuracy: 0.9694
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1738 - accuracy: 0.9536
# Epoch 24/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1582 - accuracy: 0.9456
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0894 - accuracy: 0.9773
# Epoch 26/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0582 - accuracy: 0.9796
# Epoch 27/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2444 - accuracy: 0.9343
# Epoch 28/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1569 - accuracy: 0.9479
# Epoch 29/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1089 - accuracy: 0.9649
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0722 - accuracy: 0.9819
# Đã train xong Fold  3
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_68 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_69 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_70 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_71 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_73 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_74 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_75 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_76 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_77 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_78 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_79 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_80 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_81 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_82 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_83 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  4
# Epoch 1/30
# 28/28 [==============================] - 5s 99ms/step - loss: 4.8839 - accuracy: 0.2084
# Epoch 2/30
# 28/28 [==============================] - 3s 97ms/step - loss: 3.7460 - accuracy: 0.2480
# Epoch 3/30
# 28/28 [==============================] - 3s 96ms/step - loss: 3.4753 - accuracy: 0.2729
# Epoch 4/30
# 28/28 [==============================] - 3s 96ms/step - loss: 2.2843 - accuracy: 0.4009
# Epoch 5/30
# 28/28 [==============================] - 3s 97ms/step - loss: 2.2267 - accuracy: 0.4530
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.7370 - accuracy: 0.5210
# Epoch 7/30
# 28/28 [==============================] - 3s 98ms/step - loss: 1.3384 - accuracy: 0.5866
# Epoch 8/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.4221 - accuracy: 0.6217
# Epoch 9/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.1395 - accuracy: 0.6127
# Epoch 10/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.8921 - accuracy: 0.6535
# Epoch 11/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.5814 - accuracy: 0.7814
# Epoch 12/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.5091 - accuracy: 0.8052
# Epoch 13/30
# 28/28 [==============================] - 3s 98ms/step - loss: 0.4274 - accuracy: 0.8414
# Epoch 14/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4013 - accuracy: 0.8584
# Epoch 15/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4459 - accuracy: 0.8471
# Epoch 16/30
# 28/28 [==============================] - 3s 98ms/step - loss: 0.3439 - accuracy: 0.8720
# Epoch 17/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2507 - accuracy: 0.9128
# Epoch 18/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2783 - accuracy: 0.8981
# Epoch 19/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1603 - accuracy: 0.9411
# Epoch 20/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.2324 - accuracy: 0.9162
# Epoch 21/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2574 - accuracy: 0.9117
# Epoch 22/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1772 - accuracy: 0.9400
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2265 - accuracy: 0.9207
# Epoch 24/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1834 - accuracy: 0.9388
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1417 - accuracy: 0.9558
# Epoch 26/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0968 - accuracy: 0.9615
# Epoch 27/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1518 - accuracy: 0.9456
# Epoch 28/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.2200 - accuracy: 0.9253
# Epoch 29/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1630 - accuracy: 0.9479
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1156 - accuracy: 0.9638
# Đã train xong Fold  4
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_85 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_86 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_87 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_88 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_90 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_91 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_92 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_93 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_94 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_95 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_96 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_97 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_98 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_99 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_100 (Ba  (None, 3, 3, 512)        2048
# ...
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_165 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_166 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_167 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_168 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  9
# Epoch 1/30
# 28/28 [==============================] - 5s 101ms/step - loss: 4.2963 - accuracy: 0.1993
# Epoch 2/30
# 28/28 [==============================] - 3s 96ms/step - loss: 3.2240 - accuracy: 0.2582
# Epoch 3/30
# 28/28 [==============================] - 3s 96ms/step - loss: 3.1026 - accuracy: 0.3375
# Epoch 4/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.7390 - accuracy: 0.4485
# Epoch 5/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.5853 - accuracy: 0.4564
# Epoch 6/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.1023 - accuracy: 0.5708
# Epoch 7/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.0568 - accuracy: 0.6014
# Epoch 8/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.7867 - accuracy: 0.7135
# Epoch 9/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.6739 - accuracy: 0.7554
# Epoch 10/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.4919 - accuracy: 0.8199
# Epoch 11/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.4800 - accuracy: 0.8426
# Epoch 12/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.6184 - accuracy: 0.8086
# Epoch 13/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.0903 - accuracy: 0.6206
# Epoch 14/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.7777 - accuracy: 0.7203
# Epoch 15/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.5923 - accuracy: 0.7803
# Epoch 16/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4228 - accuracy: 0.8414
# Epoch 17/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.3333 - accuracy: 0.8754
# Epoch 18/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2723 - accuracy: 0.9083
# Epoch 19/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2666 - accuracy: 0.9049
# Epoch 20/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2235 - accuracy: 0.9105
# Epoch 21/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1966 - accuracy: 0.9377
# Epoch 22/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1823 - accuracy: 0.9388
# Epoch 23/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2030 - accuracy: 0.9332
# Epoch 24/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1728 - accuracy: 0.9377
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1750 - accuracy: 0.9468
# Epoch 26/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2401 - accuracy: 0.9196
# Epoch 27/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0938 - accuracy: 0.9626
# Epoch 28/30
# 28/28 [==============================] - 3s 95ms/step - loss: 0.0853 - accuracy: 0.9740
# Epoch 29/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1408 - accuracy: 0.9468
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.0820 - accuracy: 0.9728
# Đã train xong Fold  9
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv1_1 (Conv2D)            (None, 48, 48, 64)        640
#
#  batch_normalization_170 (Ba  (None, 48, 48, 64)       256
#  tchNormalization)
#
#  conv1_2 (Conv2D)            (None, 48, 48, 64)        36928
#
#  batch_normalization_171 (Ba  (None, 48, 48, 64)       256
#  tchNormalization)
#
#  pool1_1 (MaxPooling2D)      (None, 24, 24, 64)        0
#
#  drop1_1 (Dropout)           (None, 24, 24, 64)        0
#
#  conv2_1 (Conv2D)            (None, 24, 24, 128)       73856
#
#  batch_normalization_172 (Ba  (None, 24, 24, 128)      512
#  tchNormalization)
#
#  conv2_2 (Conv2D)            (None, 24, 24, 128)       147584
#
#  batch_normalization_173 (Ba  (None, 24, 24, 128)      512
#  tchNormalization)
#
#  conv2_3 (Conv2D)            (None, 24, 24, 128)       147584
#
#  pool2_1 (MaxPooling2D)      (None, 12, 12, 128)       0
#
#  drop2_1 (Dropout)           (None, 12, 12, 128)       0
#
#  conv3_1 (Conv2D)            (None, 12, 12, 256)       295168
#
#  batch_normalization_175 (Ba  (None, 12, 12, 256)      1024
#  tchNormalization)
#
#  conv3_2 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_176 (Ba  (None, 12, 12, 256)      1024
#  tchNormalization)
#
#  conv3_3 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_177 (Ba  (None, 12, 12, 256)      1024
#  tchNormalization)
#
#  conv3_4 (Conv2D)            (None, 12, 12, 256)       590080
#
#  batch_normalization_178 (Ba  (None, 12, 12, 256)      1024
#  tchNormalization)
#
#  pool3_1 (MaxPooling2D)      (None, 6, 6, 256)         0
#
#  drop3_1 (Dropout)           (None, 6, 6, 256)         0
#
#  conv4_1 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_179 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  conv4_2 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_180 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  conv4_3 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_181 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  conv4_4 (Conv2D)            (None, 6, 6, 256)         590080
#
#  batch_normalization_182 (Ba  (None, 6, 6, 256)        1024
#  tchNormalization)
#
#  pool4_1 (MaxPooling2D)      (None, 3, 3, 256)         0
#
#  drop4_1 (Dropout)           (None, 3, 3, 256)         0
#
#  conv5_1 (Conv2D)            (None, 3, 3, 512)         1180160
#
#  batch_normalization_183 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_2 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_184 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_3 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  batch_normalization_185 (Ba  (None, 3, 3, 512)        2048
#  tchNormalization)
#
#  conv5_4 (Conv2D)            (None, 3, 3, 512)         2359808
#
#  pool5_1 (MaxPooling2D)      (None, 1, 1, 512)         0
#
#  drop5_1 (Dropout)           (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  output (Dense)              (None, 7)                 3591
#
# =================================================================
# Total params: 13,111,367
# Trainable params: 13,103,431
# Non-trainable params: 7,936
# _________________________________________________________________
# None
# Bắt đầu train Fold  10
# Epoch 1/30
# 28/28 [==============================] - 5s 99ms/step - loss: 4.0894 - accuracy: 0.2322
# Epoch 2/30
# 28/28 [==============================] - 3s 95ms/step - loss: 3.0610 - accuracy: 0.3182
# Epoch 3/30
# 28/28 [==============================] - 3s 96ms/step - loss: 3.5499 - accuracy: 0.3737
# Epoch 4/30
# 28/28 [==============================] - 3s 97ms/step - loss: 2.4973 - accuracy: 0.4507
# Epoch 5/30
# 28/28 [==============================] - 3s 96ms/step - loss: 1.5793 - accuracy: 0.5108
# Epoch 6/30
# 28/28 [==============================] - 3s 97ms/step - loss: 1.1130 - accuracy: 0.5946
# Epoch 7/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.9693 - accuracy: 0.6251
# Epoch 8/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.7445 - accuracy: 0.7044
# Epoch 9/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.6282 - accuracy: 0.7610
# Epoch 10/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.6883 - accuracy: 0.7633
# Epoch 11/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.6009 - accuracy: 0.7803
# Epoch 12/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4508 - accuracy: 0.8188
# Epoch 13/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.4475 - accuracy: 0.8313
# Epoch 14/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.4299 - accuracy: 0.8505
# Epoch 15/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.3933 - accuracy: 0.8516
# Epoch 16/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.2948 - accuracy: 0.8879
# Epoch 17/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2707 - accuracy: 0.9037
# Epoch 18/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2381 - accuracy: 0.9128
# Epoch 19/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.4077 - accuracy: 0.8664
# Epoch 20/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1638 - accuracy: 0.9388
# Epoch 21/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1771 - accuracy: 0.9343
# Epoch 22/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1750 - accuracy: 0.9309
# Epoch 23/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1447 - accuracy: 0.9502
# Epoch 24/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1430 - accuracy: 0.9558
# Epoch 25/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1694 - accuracy: 0.9411
# Epoch 26/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1676 - accuracy: 0.9490
# Epoch 27/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.2016 - accuracy: 0.9320
# Epoch 28/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1235 - accuracy: 0.9592
# Epoch 29/30
# 28/28 [==============================] - 3s 97ms/step - loss: 0.1645 - accuracy: 0.9456
# Epoch 30/30
# 28/28 [==============================] - 3s 96ms/step - loss: 0.1250 - accuracy: 0.9592
# Đã train xong Fold  10

# %%
# In kết quả tổng thể
print('* Chi tiết các fold')
for i in range(0, len(accuracy_list)):
  print(f'> Fold {i+1} - Loss: {loss_list[i]} - Accuracy: {accuracy_list[i]}%')

print('* Đánh giá tổng thể các folds:')
print(f'> Accuracy: {np.mean(accuracy_list)} (Độ lệch +- {np.std(accuracy_list)})')
print(f'> Loss: {np.mean(loss_list)}')
# Out:
# * Chi tiết các fold
# > Fold 1 - Loss: 0.09125568717718124 - Accuracy: 94.94949579238892%
# > Fold 2 - Loss: 0.679624080657959 - Accuracy: 83.67347121238708%
# > Fold 3 - Loss: 0.21445485949516296 - Accuracy: 92.85714030265808%
# > Fold 4 - Loss: 0.4175910949707031 - Accuracy: 86.73469424247742%
# > Fold 5 - Loss: 0.1091839149594307 - Accuracy: 93.87755393981934%
# > Fold 6 - Loss: 0.14367982745170593 - Accuracy: 95.91836929321289%
# > Fold 7 - Loss: 0.47764551639556885 - Accuracy: 85.71428656578064%
# > Fold 8 - Loss: 0.0634140595793724 - Accuracy: 98.97959232330322%
# > Fold 9 - Loss: 0.22023199498653412 - Accuracy: 93.87755393981934%
# > Fold 10 - Loss: 0.7280715703964233 - Accuracy: 74.48979616165161%
# * Đánh giá tổng thể các folds:
# > Accuracy: 90.10719537734985 (Độ lệch +- 6.9849683195606245)
# > Loss: 0.3145152606070042

# %%
model.save('/content/drive/MyDrive/FEC - version 2/CNN_CKplus_file_30epochs.h5')
